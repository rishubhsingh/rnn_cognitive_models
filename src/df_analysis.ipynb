# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_colwidth', -1)

# %%
# df1 = pd.read_pickle('dfs/dfresp1.pkl')
# df2 = pd.read_pickle('dfs/dfresp2.pkl')
# df3 = pd.read_pickle('dfs/dfresp3.pkl')
# df4 = pd.read_pickle('dfs/dfresp4.pkl')
# df5 = pd.read_pickle('dfs/dfresp5.pkl')
# df6 = pd.read_pickle('dfs/dfresp6.pkl')
fu6 = pd.read_pickle('dfs/full250resp6.pkl')

# %%
df6[list(df6)]['correct'][1996]
# Out:
# False

# %%
fu6[list(fu6)]['correct'][1996]
# Out:
# True

# %%
wrong1 = df2.loc[df2['correct'] == False]

# %%
wrong1[columns]
# Out:
#        correct     prediction          label  \
# 87     False    ungrammatical  grammatical
# 132    False    grammatical    ungrammatical
# 150    False    ungrammatical  grammatical
# 194    False    ungrammatical  grammatical
# 204    False    grammatical    ungrammatical
# 216    False    ungrammatical  grammatical
# 252    False    ungrammatical  grammatical
# 262    False    ungrammatical  grammatical
# 298    False    ungrammatical  grammatical
# 318    False    grammatical    ungrammatical
# 341    False    grammatical    ungrammatical
# 359    False    ungrammatical  grammatical
# 421    False    grammatical    ungrammatical
# 491    False    grammatical    ungrammatical
# 529    False    ungrammatical  grammatical
# 553    False    ungrammatical  grammatical
# 592    False    ungrammatical  grammatical
# 596    False    ungrammatical  grammatical
# 739    False    grammatical    ungrammatical
# 748    False    ungrammatical  grammatical
# ...

# %%
for i in range(8,9):
    length = df4['verb_index'][i] + 4
    act = np.asarray(df4['activations'][i]).transpose()
    sentence = df4['sentence'][i].split()
    sen = [(sentence[j]+'_'+str(j)) for j in range(len(sentence))]
    for index in range(50) :
        plt.plot(range(0, length), act[index][50-length:])
        plt.xticks(range(0, length), sentence, rotation=60)
        plt.savefig('act_imgs/p4_2_' + str(index) + '.png')
        plt.figure()

# %%
for i in range(63, 64):
    length = wrong1['verb_index'][i] + 5
    act = np.asarray(wrong1['activations'][i]).transpose()
    for index in range(50) :
        plt.plot(act[index][50-length:])
        plt.xticks(range(0, length))
        plt.figure()

# %%
for i in range(47, 50) :
    length = df5['verb_index'][i] + 5
    out = np.asarray(df5['outputs'][i]).transpose()
    sentence = df5['sentence'][i].split()
    sen = [(sentence[j]+'_'+str(j)) for j in range(len(sentence))]
    for index in range(2) :
        plt.plot(range(0, length), out[index][50-length:])
    
    plt.legend(['grammatical', 'ungrammatical'])
    plt.xticks(range(0, length), sentence, rotation=45)
    plt.savefig('p5_' + str(i-47) + '.png')
    plt.figure()

# %%
for i in [0, 52, 160, 202, 384]:
    length = df4['verb_index'][i] + 5
    out = np.asarray(df4['outputs'][i]).transpose()
    sentence = df4['sentence'][i].split()
    sen = [(sentence[j]+'_'+str(j)) for j in range(len(sentence))]
    for index in range(2) :
        plt.plot(range(0, length), out[index][50-length:])
    
    plt.legend(['grammatical', 'ungrammatical'])
    plt.xticks(range(0, length), sentence, rotation=45)
    plt.savefig('p4_wrong' + str(i) + '.png')
    plt.figure()

# %%
sen
# Out:
# [(0, 'k'),
#  (1, 'NNP'),
#  (2, 'NNP'),
#  (3, 'kit'),
#  (4, '-'),
#  (5, 'complete'),
#  (6, 'NNP'),
#  (7, 'contain'),
#  (8, 'full'),
#  (9, 'size'),
#  (10, 'pattern'),
#  (11, 'and'),
#  (12, 'whatever'),
#  (13, 'NNP'),
#  (14, 'materials'),
#  (15, 'is'),
#  (16, 'necessary')]
